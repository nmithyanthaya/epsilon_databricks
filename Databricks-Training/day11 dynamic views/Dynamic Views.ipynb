-- %%
https://docs.databricks.com/gcp/en/views/dynamic

-- %%
use catalog auto;
use nirmith_silver;

-- %%
CREATE OR REPLACE TABLE heartrate_device (device_id INT, mrn STRING, name STRING, time TIMESTAMP, heartrate DOUBLE);

INSERT INTO heartrate_device VALUES
  (23, "40580129", "Nicholas Spears", "2020-02-01T00:01:58.000+0000", 54.0122153343),
  (17, "52804177", "Lynn Russell", "2020-02-01T00:02:55.000+0000", 92.5136468131),
  (37, "65300842", "Samuel Hughes", "2020-02-01T00:08:58.000+0000", 52.1354807863),
  (23, "40580129", "Nicholas Spears", "2020-02-01T00:16:51.000+0000", 54.6477014191),
  (17, "52804177", "Lynn Russell", "2020-02-01T00:18:08.000+0000", 95.033344842);
  
SELECT * FROM heartrate_device

-- %%
CREATE OR REPLACE VIEW nirmith_gold.agg_heartrate AS (
  SELECT mrn, name, MEAN(heartrate) avg_heartrate, DATE_TRUNC("DD", time) date
  FROM heartrate_device
  GROUP BY mrn, name, DATE_TRUNC("DD", time)
);
SELECT * FROM nirmith_gold.agg_heartrate

-- %% [markdown]
-- ### Column-level permissions

-- %%
CREATE OR REPLACE VIEW nirmith_gold.agg_heartrate AS (
  SELECT 
  CASE WHEN
    is_account_group_member('de') THEN mrn
    ELSE 'REDACTED'
  END AS mrn, 
  name, 
  MEAN(heartrate) avg_heartrate, 
  DATE_TRUNC("DD", time) date
  FROM heartrate_device
  GROUP BY mrn, name, DATE_TRUNC("DD", time)
);

-- %%
CREATE OR REPLACE VIEW nirmith_gold.agg_heartrate AS (
  SELECT 
  CASE WHEN
    is_account_group_member('account users') THEN 'REDACTED'
    ELSE mrn
  END AS mrn, 
  name, 
  MEAN(heartrate) avg_heartrate, 
  DATE_TRUNC("DD", time) date
  FROM heartrate_device
  GROUP BY mrn, name, DATE_TRUNC("DD", time)
);

-- %%
select * from auto.nirmith_gold.agg_heartrate

-- %% [markdown]
-- ### Row-level permissions

-- %%
SELECT * FROM heartrate_device

-- %%
create or replace view auto.nirmith_gold.heartrate 
as 
SELECT * FROM heartrate_device  
where
CASE
    WHEN is_account_group_member('account users') THEN device_id>17
    ELSE True
  END;

-- %%
select * from auto.nirmith_gold.heartrate

-- %%
Task : redacted mrn column and records where device_id>17 or heatrate

-- %%
CREATE OR REPLACE VIEW nirmith_gold.agg_heartrate AS (
  SELECT 
    CASE 
      WHEN is_account_group_member('account users') THEN 'REDACTED'
      ELSE mrn
    END AS mrn, 
    name, 
    MEAN(heartrate) AS avg_heartrate, 
    DATE_TRUNC("DD", time) AS date
  FROM heartrate_device
  WHERE 
   CASE
    --WHEN is_account_group_member('account users') THEN device_id > 17
    WHEN is_account_group_member('account users') THEN heartrate>53
    ELSE True
  END
  GROUP BY mrn, name, DATE_TRUNC("DD", time)
);

-- %%
select * from nirmith_gold.agg_heartrate

-- %%
CREATE OR REPLACE FUNCTION datamask(x STRING)
  RETURNS STRING
  RETURN CONCAT(REPEAT("*", LENGTH(x) - 2), RIGHT(x, 2)
);

-- %%
select datamask("nirmithraj@gmail.com") as mask

-- %%
CREATE OR REPLACE VIEW nirmith_gold.agg_heartrate AS (
  SELECT 
  CASE WHEN
    is_account_group_member('de') THEN datamask(mrn)
    ELSE mrn
  END AS mrn, 
  name, 
  MEAN(heartrate) avg_heartrate, 
  DATE_TRUNC("DD", time) date
  FROM heartrate_device
  GROUP BY mrn, name, DATE_TRUNC("DD", time)
);

-- %%
select * from nirmith_gold.agg_heartrate
